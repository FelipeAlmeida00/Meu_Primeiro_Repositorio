# %% [markdown]
# <a href="https://colab.research.google.com/github/FelipeAlmeida00/Meu_Primeiro_Repositorio/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exemplos e Informações de "codagem" em Python

# %%
print("LivePython")

num1 = int (input('Informe um valor: '))
num2 = int (input('Informe outro valor: '))
soma = num1 + num2

# exemplos de print

print('A soma e ', soma)
print('A soma é %d' % soma)
print('A soma entre %d e %d é igual a %d' % (num1, num2, soma))
print(f'A soma é {num1+num2}')
print(f'A soma é {soma}')
print(f'A soma entre {num1} + {num2} é {soma}')

# %%
import random 
y = random.random()
print(y)
print(5 + y)
print(int (10 * y))
print(50 + y * 20)

# %%
num = int (input('Entre com um Valor: '))

# divisão que o resultado é o resto.
if(num % 2 == 0):
  print('O numero é par')
# Out:
# Entre com um Valor: 8
# O numero é par

# %%
op = input('Somar (S) ou multiplicar (M)?')
op = op.upper()
if(op == 'S'):
  x = int(input('Digite um valor para x: '))
  y = int(input('Digite um valor para y: '))
  r = x + y
  print('A soma é' ,r)
elif (op == 'M'):
  x = int(input('Digite um valor para x:'))
  y = int(input('Digite um valor para y:'))
  r = x * y
  print('A multiplicação é' ,r)
else:
  print('Opção invalida')
# Out:
# Somar (S) ou multiplicar (M)?m
# Digite um valor para x:5
# Digite um valor para y:6
# A multiplicação é 30

# %%
# while
x = 0
while x < 5:
  print(x)
  x += 1 # x = x +1

# %%
#fatorial

numero = int(input('Fatorial de: '))
resultado = 1
for n in range(1,numero+1):
  resultado *= n 
print(resultado)
# Out:
# Fatorial de: 9
# 362880

# %%
#vetores

nome1 =  input('Entre com o nome do aluno 1: ')
nome2 =  input('Entre com o nome do aluno 2: ')
nome3 =  input('Entre com o nome do aluno 3: ')

nota1 = float(input('informe a nota de ' + nome1 +': '))
nota2 = float(input('informe a nota de ' + nome2 +': '))
nota3 = float(input('informe a nota de ' + nome3 +': '))

media = (nota1 + nota2 + nota3) / 3
print('A media da turma é: ', media)
if(nota1 > media):
  print('Parabens ', nome1)
if(nota2 > media):
  print('Parabens ', nome2)
if(nota3 > media):
  print('Parabens ', nome3)

# %% [markdown]
# # Python, O.O ( Orientada a Objeto) curso, exemplos ....

# %%
#Definição de Classe 

class Aluno:
  def _init_(self, nome):
    self.nome = nome
  def _str_(self):
    return self.nome

# %%
class Automovel:
  def dirigir(self, velocidade):
    print ('Estou dirigindo a %')

# %%
class Ponto:
  def distancia(self):
    return ((self.x ** 2) + (self .y ** 2)) ** 0.5

p = Ponto(0,5)
print(p.distancia())
